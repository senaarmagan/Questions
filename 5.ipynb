# %%
import pandas as pd

# %%
df = pd.read_csv("country_vaccination_stats.csv")
df.head(15)
# Out:
#       country        date  daily_vaccinations   vaccines
# 0   Argentina  12/29/2020                 NaN  Sputnik V
# 1   Argentina  12/30/2020             15656.0  Sputnik V
# 2   Argentina  12/31/2020             15656.0  Sputnik V
# 3   Argentina    1/1/2021             11070.0  Sputnik V
# 4   Argentina    1/2/2021              8776.0  Sputnik V
# 5   Argentina    1/3/2021              7400.0  Sputnik V
# 6   Argentina    1/4/2021              6483.0  Sputnik V
# 7   Argentina    1/5/2021              7984.0  Sputnik V
# 8   Argentina    1/6/2021              8173.0  Sputnik V
# 9   Argentina    1/7/2021              8363.0  Sputnik V
# 10  Argentina    1/8/2021             10519.0  Sputnik V
# 11  Argentina    1/9/2021             11942.0  Sputnik V
# 12  Argentina   1/10/2021             13365.0  Sputnik V
# 13  Argentina   1/11/2021             14788.0  Sputnik V
# 14  Argentina   1/12/2021             14056.0  Sputnik V

# %%
df.isnull().sum()
# Out:
# country                0
# date                   0
# daily_vaccinations    60
# vaccines               0
# dtype: int64

# %%
df[["country","daily_vaccinations"]]
# Out:
#         country  daily_vaccinations
# 0     Argentina                 NaN
# 1     Argentina             15656.0
# 2     Argentina             15656.0
# 3     Argentina             11070.0
# 4     Argentina              8776.0
# ...         ...                 ...
# 1497      Wales             11105.0
# 1498      Wales             12318.0
# 1499      Wales             15148.0
# 1500      Wales             17371.0
# 1501      Wales             17063.0
#
# [1502 rows x 2 columns]

# %%
df.groupby("country").agg({"daily_vaccinations":["median"]})
# Out:
#                      daily_vaccinations
#                                  median
# country
# Argentina                       11704.0
# Austria                          7953.0
# Bahrain                          3871.0
# Belgium                          3634.0
# Brazil                          27304.0
# Bulgaria                         1013.0
# Canada                          11577.5
# Chile                            1328.5
# China                          299107.5
# Costa Rica                        763.0
# Croatia                          2497.5
# Cyprus                            729.5
# Czechia                          5812.0
# Denmark                          7139.0
# Ecuador                           108.0
# England                        115637.0
# Estonia                          1051.5
# Finland                          2332.0
# France                          43961.0
# Germany                         52415.5
# Gibraltar                         744.0
# ...

# %%
df_new = df.groupby('country')['daily_vaccinations'].median()
order = df_new.sort_values(ascending=False)
order
# Out:
# country
# United States           399093.0
# China                   299107.5
# India                   182551.5
# Turkey                  154397.5
# United Kingdom          129663.0
# England                 115637.0
# Israel                   95621.0
# United Arab Emirates     88134.5
# Spain                    56505.0
# Germany                  52415.5
# Italy                    45417.0
# France                   43961.0
# Brazil                   27304.0
# Russia                   25299.0
# Poland                   23659.0
# Saudi Arabia             16843.0
# Romania                  13214.0
# Indonesia                13200.0
# Argentina                11704.0
# Canada                   11577.5
# Austria                   7953.0
# Denmark                   7139.0
# Netherlands               6881.0
# Ireland                   6607.0
# Portugal                  5946.5
# Scotland                  5821.0
# Czechia                   5812.0
# Mexico                    5682.0
# ...

# %%
df_new = df.groupby('country')['daily_vaccinations'].median()
order = df_new.sort_values(ascending=False)
order.head(3)
# Out:
# country
# United States    399093.0
# China            299107.5
# India            182551.5
# Name: daily_vaccinations, dtype: float64
